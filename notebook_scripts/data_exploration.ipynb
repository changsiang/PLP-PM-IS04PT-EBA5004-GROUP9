# %%
import warnings
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
import os
import json

warnings.filterwarnings('ignore', category=FutureWarning)

# %%
drive.mount('/content/drive/')
os.chdir('drive/MyDrive/Colab Notebooks/PLP_Practice_Module/data')
# Out:
# Mounted at /content/drive/

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/PLP_Practice_Module/data

# %%
with open('data.json') as f:
  data = json.load(f)

# %%
len(data)
# Out:
# 75

# %%
question_df = pd.DataFrame(columns=['id', 'question', 'type'])

# %%
for key, value in data.items():
  question_type = 'clinical' if value['question_type'] == 'C' else 'biological'
  new_row = { 'id': key, 'question': value['question'], 'type': question_type }
  question_df = question_df.append(new_row, ignore_index=True)
  print(key, value['question'], question_type)
# Out:
# 1 What causes muscle spasm? clinical
# 2 What does duloxetine do? biological
# 3 How can i reduce my potassium levels? clinical
# 4 How is diabetes diagnosed? clinical
# 5 How to treat a bakers cyst? clinical
# 6 What is the best thyroid drug? biological
# 7 How is strep throat treated? clinical
# 8 Who is prescribed perphenazine? clinical
# 9 How to dislodge meat from throat? clinical
# 10 I have a cut on my arm and my fingers are sweating and i feel pain in my fingers. What can i do to stop the pain? clinical
# 11 How to treat phda1? biological
# 12 How can asthma be prevented? clinical
# 13 How to eliminate nocturnal atrial fibrillation? clinical
# 14 How to increase body immunity against covid 19? clinical
# 15 How does human body maintain hypokalemia shock homeostasis? biological
# 16 How long to recover immune system from prednisone treatment? biological
# 17 How do you assist an unconscious victim who is already vomiting? clinical
# 18 To treat abnormal ketones result of pregnant woman what food should be eaten? clinical
# 19 Does prescribing dopamine in the early stages of parkinson’s disease help patients? clinical
# 20 At what strength is prozac usually begun for a patient changing from another antidepressant? clinical
# 21 How do you check for a hernia? clinical
# 22 Where do bhd patients get cysts? clinical
# 23 How is phenylketonuria inherited? biological
# 24 Can you take lorazepam and buspirone at the same time? clinical
# 25 When do monoclonal antibodies have to be given for covid? biological
# 26 How long is covid 19 communicable? clinical
# 27 How safe is the covid vaccine? clinical
# 28 How can covid cause cell injury? biological
# 29 Is there any nutrition which can increase body immunity against covid 19? clinical
# 30 How long will you be positive for covid after illness? clinical
# 31 What medications are used to treat tardive dyskinesia? clinical
# 32 What bp meds should not be taken if person has mthfr genetic variant? biological
# 33 How long does it take for gabapentin to go out of the body? biological
# 34 Stage 3 kidney disease. Is there a shot you can take that will keep you off dialysis? clinical
# 35 How often should i have a bone density test? clinical
# 36 I have had a kidney stone in for almost three years. It’s killing me and none even noticed it till now, even on ultrasound, how will it be taken out? clinical
# 37 Do memory problems improve over time when taking pregabalin? clinical
# 38 How to heal a pressure wound on the ear? clinical
# 39 What is a biomarker? biological
# 40 Could compression therapy with bandage raise your blood pressure? clinical
# 41 What could possibly cause a cyst in the lower pole of the kidney? biological
# 42 What are the types of histone proteins? biological
# 43 How does pacemaker work? clinical
# 44 What percent of blood loss shows the sign symptom of hypovolemic shocks begin? clinical
# 45 Do i keep a pressure sore covered and moist and what kind of ointment to use? clinical
# 46 How does cystic fibrosis affect cell membrane? biological
# 47 What causes low alkaline phosphate levels? biological
# 48 I have lupus. What can i do to stop it? clinical
# 49 What causes pitted edema in legs? clinical
# 50 What does a negative result of a c-reactive protein test indicate? biological
# 51 What is islet cell antibody group? biological
# 52 What level of gene expression from transcription to protein does turner syndrome impact? biological
# 53 Why do blood sugars become elevated in the afternoon? clinical
# 54 Why does bloodwork show decreasing levels of hcg in a pregnant woman? clinical
# 55 Does phosphatidylserine support memory in people with me/cfs? clinical
# 56 How common is pallister-hall syndrome? clinical
# 57 What is neuropathic pain? i was diagnosed with neuropathic pain after being in a car accident where the airbag was not deployed i had 27 facial fractures, thereby diagnosed with the neuropathic pain clinical
# 58 How often can i get a covid-19 vaccine? clinical
# 59 Had pfizer covid vac. Should i get moderna booster? clinical
# 60 Can a covid test results be a false positive if your just getting over a cold and allergies? clinical
# 61 Is zinc gluconate or zinc citrate easiest to metabolize by the body? biological
# 62 I have a hydroxyz pill with h and 502 on one side and white on reverse. Can i take that pill with a benedryl? clinical
# 63 Does anastrozole causes hair loss & dry patches in your scalp? clinical
# 64 How is scn1a gene disorder tested? clinical
# 65 Ratio of omega 6's to omega 3's; how important is it? clinical
# 66 Nephrotic syndrome what happens when gets bad? biological
# 67 How much physical therapy for knee replacement is needed? clinical
# 68 Why is transferrin and iron low in covid patients but ferritin high? clinical
# 69 What are prevention suggestions and strategies pertaining to postpartum depression? clinical
# 70 What happens wen you don't get enough vitamin b6? biological
# 71 What happens in the body to cause achondroplasia? biological
# 72 What is newborn metabolic screening? what can the results tell doctors? clinical
# 73 In adult patients with total hip replacements how effective is pain medication in recovery? clinical
# 74 Why do i have to constantly clear my throat and cough up flem? clinical
# 75 What is a gene affected by sickle cell anemia? biological

# %%
question_df.head()
# Out:
#   id                               question        type
# 0  1              What causes muscle spasm?    clinical
# 1  2               What does duloxetine do?  biological
# 2  3  How can i reduce my potassium levels?    clinical
# 3  4             How is diabetes diagnosed?    clinical
# 4  5            How to treat a bakers cyst?    clinical

# %%
question_df.to_csv('./questions_df.csv', index=False)

# %%
question_df['type'].value_counts()
# Out:
# clinical      52
# biological    23
# Name: type, dtype: int64

# %%
def extract_abstract_and_adaptation(abstract):
  result = []
  for _, value in abstract.items():
    if isinstance(value, str):
      continue
    title = value['Title']
    abstract = value['abstract']
    adapts = value['adaptations']
    for _, adapt in adapts.items():
      result.append({'title': title, 'abstract': abstract, 'adaptation': adapt})
  return result

# %%
reshape_data = {}
pair_match_df = pd.DataFrame(columns=['seqA', 'seqB', 'question', 'question_type'])

# %%
for key, value in data.items():
  reshape_adapt = extract_abstract_and_adaptation(value)
  reshape_data[key] = reshape_adapt

# %%
for idx, items_array in reshape_data.items():
  for item in items_array:
    abstract = item['abstract']
    adaptation = item['adaptation']
    if len(abstract) == len(adaptation):
      for key, value in abstract.items():
        new_row = { 'seqA': value, 'seqB': adaptation[key], 'question': data[idx]['question'], 'question_type': data[idx]['question_type'] }
        pair_match_df = pair_match_df.append(new_row, ignore_index=True)

# %%
pair_match_df.head()
# Out:
#                                                 seqA  \
# 0  Muscle cramps are a common problem characteriz...
# 1  These true cramps, which originate from periph...
# 2  Medical history, physical examination, and a l...
# 3  Despite the "benign" nature of cramps, many pa...
# 4  Treatment options are guided both by experienc...
#
#                                                 seqB  \
# 0  Muscle cramps are a common problem represented...
# 1  These true cramps, coming from nerves outside ...
# 2  Medical history, physical check-up, and lab sc...
# 3  Despite their harmless nature, cramps are unco...
# 4  Experience and limited medical studies guide t...
#
#                     question question_type
# 0  What causes muscle spasm?             C
# 1  What causes muscle spasm?             C
# 2  What causes muscle spasm?             C
# 3  What causes muscle spasm?             C
# 4  What causes muscle spasm?             C

# %%
# save reshaped data set first..
pair_match_df.to_csv('./pair_match_df.csv', index=False)

# %%
abstract_adaptation_pair_df = pd.DataFrame(columns=['abstract', 'adaptation', 'question', 'category', 'question_type'])

# %%
for idx, items_array in reshape_data.items():
  for item in items_array:
    abstract = item['abstract']
    adaptation = item['adaptation']
    new_row = { 'abstract': ' '.join(abstract.values()), 'adaptation': ' '.join(adaptation.values()), 'question': data[idx]['question'], 'category': idx, 'question_type': data[idx]['question_type']}
    abstract_adaptation_pair_df = abstract_adaptation_pair_df.append(new_row, ignore_index=True)

# %%
abstract_adaptation_pair_df.head()
# Out:
#                                             abstract  \
# 0  Muscle cramps are a common problem characteriz...
# 1  The dystonias are a group of disorders charact...
# 2  Muscle cramps result in continuous, involuntar...
# 3  Exercise-Associated Muscle Cramps (EAMC) are a...
# 4  Muscular cramp is a common symptom in healthy ...
#
#                                           adaptation  \
# 0  Muscle cramps are a common problem represented...
# 1  Dystonias are disorders with a lot of uncontro...
# 2  Muscle cramps cause constant and unintended co...
# 3  Exercise-Associated Muscle Cramps (EAMC) are a...
# 4  Muscle cramps are common in healthy people, es...
#
#                     question category question_type
# 0  What causes muscle spasm?        1             C
# 1  What causes muscle spasm?        1             C
# 2  What causes muscle spasm?        1             C
# 3  What causes muscle spasm?        1             C
# 4  What causes muscle spasm?        1             C

# %%
abstract_adaptation_pair_df.to_csv('./abstract_adaptation_pair_df.csv', index=False)
